# %%
# !pip install colombia_hydrodata

# %%
from colombia_hydrodata import Client

client = Client()
station = client.fetch_station("29037020")
print(station)

# %%
dataset = station["CAUDAL@HIS_Q_MEDIA_M"]
print(dataset)
